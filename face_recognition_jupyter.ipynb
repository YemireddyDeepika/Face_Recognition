# %%
# %run face_recognition_pca_ann.py
# Out:
# Loading dataset...
#
# Dataset path: C:\Users\Deepika\Desktop\Face_recognition\dataset\faces
# Path exists: True
# Reading person: Aamir
# Reading person: Ajay
# Reading person: Akshay
# Reading person: Alia
# Reading person: Amitabh
# Reading person: Deepika
# Reading person: Disha
# Reading person: Farhan
# Reading person: Ileana
#
# Dataset shape: (450, 10000)
# Number of persons: 9
#
# Applying PCA...
# Training ANN...
#
#
# Final Accuracy: 68.15%
